# %%
import json
def load_data(filename):
    with open(filename,"r") as file:
        return json.load(file)

#function to find pages a user might like on common interest
def find_pages_you_might_like(user_id,data):
    user_pages={}
    for user in data["users"]:
        user_pages[user["id"]]=set(user["liked_pages"])

    #if user not found, return empty list
    if user_id not in user_pages:
        return[] 

    user_liked_pages=user_pages[user_id]
    page_suggestions={} 

    for other_user,pages in user_pages.item():
        if other_user!=user_id:
            shared_pages=user_liked_pages.intersection(pages)
            for page in pages:
                if page not in user_liked_pages:
                    page_suggestions[page]=page_suggestions.get(page,0)+len(shared_pages)


    #sort recommended pages based on the number of shared interactions
    sorted_pages=sorted(page_suggestions.items(),key=lambda x:x[1],reverse=True)
    return [page_id for page_id, _ in sorted_pages]

#loading the data
data=load_data("massive_data.json")
user_id=1
pages_recommendations=find_pages_you_might_like(user_id,data)
print(f"Pages user {user_id} might like : {pages_recommendations}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 34
#      32 data=load_data("massive_data.json")
#      33 user_id=1
# ---> 34 pages_recommendations=find_pages_you_might_like(user_id,data)
#      35 print(f"Pages user {user_id} might like : {page_recommendations}")
#
# Cell In[7], line 19, in find_pages_you_might_like(user_id, data)
#      16 user_liked_pages=user_pages[user_id]
#      17 page_suggestions={}
# ---> 19 for other_user,pages in user_pages.item():
#      20     if other_user!=user_id:
#      21         shared_pages=user_liked_pages.intersection(pages)
#
# AttributeError: 'dict' object has no attribute 'item'
